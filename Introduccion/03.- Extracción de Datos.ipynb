# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Extracción de Datos de Diferentes Fuentes</h1>
# </div>

# %% [markdown]
# La **extracción de datos** es el proceso de obtener información relevante desde diversas fuentes y formatos, como archivos de texto, hojas de cálculo, bases de datos, imágenes, archivos web, APIs, entre otros. En la actualidad, los datos se encuentran dispersos y almacenados en múltiples formas, por lo que saber cómo acceder, limpiar y transformar estos datos es una habilidad fundamental.
#
# #### ¿Por qué es importante la extracción de datos?
#
# - Permite **integrar información** de diferentes sistemas y plataformas.
# - Es el primer paso para el **análisis de datos** y la toma de decisiones basada en evidencia.
# - Facilita la **automatización** de procesos y la actualización constante de información.
# - Es esencial para la **preparación de datos** en proyectos de ciencia de datos e inteligencia artificial.
#
# En proyectos de **Inteligencia Artificial (IA)**, la calidad y diversidad de los datos es clave para entrenar modelos robustos y precisos. La extracción de datos permite:
#
# - **Construir datasets** a partir de fuentes reales y actualizadas.
# - **Preprocesar y limpiar** la información antes de alimentar algoritmos de machine learning.
# - **Enriquecer modelos** combinando datos estructurados (tablas, bases de datos) y no estructurados (texto, imágenes, audio).
# - **Automatizar la recolección** de datos para sistemas de IA en producción.
#
# Dominar las técnicas de extracción de datos te permitirá abordar problemas complejos, crear soluciones inteligentes y aprovechar el potencial de la IA en cualquier área profesional.

# %% [markdown]
# <div style="background-color:#e6f2ff; border-left:4px solid #000047; padding:10px;">
# En este notebook aprenderás a extraer datos desde archivos CSV, Excel, texto, JSON, XML, imágenes, HTML y SHP, utilizando Python y sus principales librerías.
# </div>

# %% [markdown]
# ## Cargar archivos

# %%
# Almacenamos la ruta de los archivos en una variable
ruta='Data/'

# %% [markdown]
# # Archivos Excel y CSV
#
# Los archivos Excel (`.xlsx`, `.xls`) y CSV (`.csv`) son formatos tabulares ampliamente utilizados para almacenar datos estructurados. Python, a través de la librería `pandas`, permite leer y manipular estos archivos de manera sencilla y eficiente.

# %%
import pandas as pd

# %%
df_csv = pd.read_csv(ruta+'df_tabla2.csv')
print('Contenido del archivo CSV:')
print(df_csv)
# Out:
# Contenido del archivo CSV:
#    Unnamed: 0        country  rank  year   gdppc
# 0           0  Liechtenstein     1  2008  141100
# 1           1      Singapore     4  2011   59900
# 2           2         Panama    68  2011   13600

# %% [markdown]
# # Archivos de texto
# ### De texto a `DataFrame`

# %% [markdown]
# `pd.read_fwf` de pandas se utiliza para leer archivos de texto con columnas de ancho fijo (fixed-width formatted lines) y cargarlos en un DataFrame

# %%
# Extracción a partir de texto separado por tabular
pd.read_fwf(ruta+'texto_2.txt',header=None) # No se puede especificar el separador
# Out:
#          0    1   2
# 0      Ana  1.0  10
# 1     Beto  1.1  10
# 2  Alfredo  6.0   9
# 3  Armando  5.0   9

# %% [markdown]
# `read_table` de pandas se utiliza para leer archivos de texto delimitados (por defecto, separados por tabulaciones) y cargarlos en un DataFrame

# %%
pd.read_table(ruta+'texto_2.txt',header=None) # sep='\t'
# Out:
#           0    1   2
# 0  Ana       1.0  10
# 1  Beto      1.1  10
# 2  Alfredo   6.0   9
# 3  Armando   5.0   9

# %%
# Extracción a partir de texto separado por comas
pd.read_table(ruta+'texto_1.txt',sep=',',header=None)
# Out:
#          0    1   2
# 0      Ana  1.0  10
# 1     Beto  1.1  10
# 2  Alfredo  6.0   9
# 3  Armando  5.0   9

# %%
pd.read_table(ruta+'texto_1.txt',sep=' ',header=None)
# Out:
#           0     1   2
# 0      Ana,    1,  10
# 1     Beto,  1.1,  10
# 2  Alfredo,    6,   9
# 3  Armando,    5,   9

# %%
pd.read_csv(ruta+'texto_2.txt',header=None,sep='\t') # sep=','
# Out:
#           0    1   2
# 0  Ana       1.0  10
# 1  Beto      1.1  10
# 2  Alfredo   6.0   9
# 3  Armando   5.0   9

# %%
# Conversión de archivo a variable
file=open(ruta+'texto_3.txt')     # Abrir...
texto=file.read()
file.close()                      # ...despues cerrar

# %%
texto
# Out:
# 'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivÃ\xada un hidalgo de los de lanza en astillero, adarga antigua, rocÃ³n flaco y galgo corredor. Una olla de algo mÃ¡s vaca que carnero, salpicÃ³n las mÃ¡s noches, duelos y quebrantos los sÃ¡bados, lantejas los viernes, algÃºn palomino de aÃ±adidura los domingos, consumÃ\xadan las tres partes de su hacienda. El resto della concluÃ\xadan sayo de velarte, calzas de velludo para las fiestas, con sus pantuflos de lo mesmo, y los dÃ\xadas de entresemana se honraba con su vellorÃ\xad de lo mÃ¡s fino. TenÃ\xada en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que asÃ\xad ensillaba el rocÃ\xadn como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta aÃ±os; era de complexiÃ³n recia, seco de carnes, enjuto de rostro, gran madrugador y amigo de la caza. Quieren decir que tenÃ\xada el sobrenombre de Quijada, o Quesada, q
# ...

# %%
# Si ocurre un error durante la ejecución, la variable file se cierra siempre:
with open(ruta+'texto_3.txt') as file:
  texto=file.read()

# %%
texto
# Out:
# 'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivÃ\xada un hidalgo de los de lanza en astillero, adarga antigua, rocÃ³n flaco y galgo corredor. Una olla de algo mÃ¡s vaca que carnero, salpicÃ³n las mÃ¡s noches, duelos y quebrantos los sÃ¡bados, lantejas los viernes, algÃºn palomino de aÃ±adidura los domingos, consumÃ\xadan las tres partes de su hacienda. El resto della concluÃ\xadan sayo de velarte, calzas de velludo para las fiestas, con sus pantuflos de lo mesmo, y los dÃ\xadas de entresemana se honraba con su vellorÃ\xad de lo mÃ¡s fino. TenÃ\xada en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que asÃ\xad ensillaba el rocÃ\xadn como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta aÃ±os; era de complexiÃ³n recia, seco de carnes, enjuto de rostro, gran madrugador y amigo de la caza. Quieren decir que tenÃ\xada el sobrenombre de Quijada, o Quesada, q
# ...

# %%
# Separamos cada palabra de la variable de texto
texto.split()
# Out:
# ['En',
#  'un',
#  'lugar',
#  'de',
#  'la',
#  'Mancha,',
#  'de',
#  'cuyo',
#  'nombre',
#  'no',
#  'quiero',
#  'acordarme,',
#  'no',
#  'ha',
#  'mucho',
#  'tiempo',
#  'que',
#  'vivÃ\xada',
#  'un',
#  'hidalgo',
#  'de',
#  'los',
#  'de',
#  'lanza',
#  'en',
#  'astillero,',
#  'adarga',
#  'antigua,',
#  'rocÃ³n',
#  'flaco',
#  'y',
#  'galgo',
#  'corredor.',
#  'Una',
#  'olla',
#  'de',
#  'algo',
#  'mÃ¡s',
#  'vaca',
#  'que',
#  'carnero,',
#  'salpicÃ³n',
#  'las',
#  'mÃ¡s',
#  'noches,',
#  'duelos',
#  'y',
#  'quebrantos',
#  'los',
#  'sÃ¡bados,',
#  'lantejas',
#  'los',
#  'viernes,',
#  'algÃºn',
#  'palomino',
#  'de',
#  'aÃ±adidura',
#  'los',
#  'domingos,',
#  'consumÃ\xadan',
#  'las',
#  'tres',
#  'partes',
#  'de',
#  'su',
#  'hacienda.',
#  'El',
#  'resto',
#  'della',
#  'concluÃ\xadan',
#  'sayo',
#  'de',
#  'velarte,',
#  'calzas',
#  'de',
#  'velludo',
#  'para',
#  'las',
#  'fiestas,',
#  'con',
#  'sus',
#  'pantuflos',
#  'de',
# ...

# %%
texto.split?
# Out:
# Signature: texto.split(sep=None, maxsplit=-1)
# Docstring:
# Return a list of the substrings in the string, using sep as the separator string.
#
#   sep
#     The separator used to split the string.
#
#     When set to None (the default value), will split on any whitespace
#     character (including \n \r \t \f and spaces) and will discard
#     empty strings from the result.
#   maxsplit
#     Maximum number of splits.
#     -1 (the default value) means no limit.
#
# Splitting starts at the front of the string and works to the end.
#
# Note, str.split() is mainly useful for data that has been intentionally
# delimited.  With natural text that includes punctuation, consider using
# the regular expression module.
# Type:      builtin_function_or_method

# %% [markdown]
# ### Expresiones regulares

# %% [markdown]
# Las <b>expresiones regulares</b> son patrones que permiten buscar, extraer, validar y manipular texto de manera flexible y eficiente. Son esenciales para limpiar datos, extraer información y validar formatos en archivos de texto.
#
# ### Caracteres y operadores básicos
#
# | Símbolo | Significado | Ejemplo |
# |---------|-------------|---------|
# | `.`     | Cualquier carácter | `a.b` encuentra 'acb', 'aab', etc. |
# | `\d`   | Dígito (0-9) | `\d\d` encuentra dos dígitos |
# | `\w`   | Carácter alfanumérico | `\w+` encuentra palabras |
# | `\s`   | Espacio en blanco | `\s+` encuentra espacios |
# | `*`     | Cero o más repeticiones | `ab*` encuentra 'a', 'ab', 'abb', ... |
# | `+`     | Una o más repeticiones | `ab+` encuentra 'ab', 'abb', ... |
# | `?`     | Cero o una repetición | `ab?` encuentra 'a', 'ab' |
# | `^`     | Inicio de línea | `^Hola` encuentra líneas que empiezan con 'Hola' |
# | `$`     | Fin de línea | `mundo$` encuentra líneas que terminan con 'mundo' |
# | `[abc]` | Cualquier carácter a, b o c | `[aeiou]` encuentra vocales |
# | `( )`   | Agrupación | `(abc)+` encuentra 'abc', 'abcabc', ... |
#
# ### Funciones principales en Python (`re`)
#
# - `re.search(patron, texto)`: Busca el patrón en el texto y devuelve el primer resultado.
# - `re.match(patron, texto)`: Verifica si el patrón coincide al inicio del texto.
# - `re.findall(patron, texto)`: Devuelve todas las coincidencias del patrón.
# - `re.sub(patron, reemplazo, texto)`: Reemplaza coincidencias por otro texto.
#
# ### Ejemplo: Buscar correos electrónicos

# %%
import re

texto_correo = "Mi correo es gdesirena@outlook.mx pero anteriormente usaba gdesirena@gmail.com"
patron = r"\w+@\w+\.\w+"

# %% [markdown]
# ### Ejemplo: Extraer dominios de correos

# %%
dominios = re.findall(r'@([\w\.-]+)', texto_correo)
print('Dominios encontrados:', dominios)
# Out:
# Dominios encontrados: ['outlook.mx', 'gmail.com']

# %% [markdown]
# ### Ejemplo: Buscar fechas en formato DD/MM/AAAA

# %%
texto_fechas = 'algunas fechas importantes son 15/09/2023 y 01/01/2024.' 
fechas = re.findall(r'\b\d{2}/\d{2}/\d{4}\b', texto_fechas)
print('Fechas encontradas:', fechas)
# Out:
# Fechas encontradas: ['15/09/2023', '01/01/2024']

# %% [markdown]
# ### Ejemplo: Validar números de teléfono
#
# Busca números en formato internacional (+52 33 1234 5678):

# %%
texto_tel = 'Mi número es +52 33 1234 5678 y el de mi amigo es +52 55 8765 4321.'
patron_tel = r'\+\d{2}\s\d{2}\s\d{4}\s\d{4}'
telefonos = re.findall(patron_tel, texto_tel)
print('Teléfonos encontrados:', telefonos)
# Out:
# Teléfonos encontrados: ['+52 33 1234 5678', '+52 55 8765 4321']

# %% [markdown]
# ### Ejemplo: Reemplazo de texto
#
# Reemplaza todos los dígitos por 'X':

# %%
texto = 'Mi clave es 1234 y mi usuario es user01.'
nuevo_texto = re.sub(r'\d', 'X', texto)
print(nuevo_texto)
# Out:
# Mi clave es XXXX y mi usuario es userXX.

# %% [markdown]
# ### Ejemplo: Conteo de palabras usando regex

# %%
L = re.split(r'\W', texto)
S = set(L)
S.discard('')
d = {}
for palabra in S:
    d[palabra] = len(re.findall(palabra, texto, flags=re.I))
d
# Out:
# {'clave': 1,
#  'Mi': 2,
#  '1234': 1,
#  'es': 2,
#  'usuario': 1,
#  'mi': 2,
#  'user01': 1,
#  'y': 1}

# %% [markdown]
# ### Ejercicio 1
#
# Busca todas las palabras que empiezan con la letra 'u' en el texto anterior.

# %%
with open(ruta+'texto_3.txt') as file:
  texto=file.read()
texto
# Out:
# 'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivÃ\xada un hidalgo de los de lanza en astillero, adarga antigua, rocÃ³n flaco y galgo corredor. Una olla de algo mÃ¡s vaca que carnero, salpicÃ³n las mÃ¡s noches, duelos y quebrantos los sÃ¡bados, lantejas los viernes, algÃºn palomino de aÃ±adidura los domingos, consumÃ\xadan las tres partes de su hacienda. El resto della concluÃ\xadan sayo de velarte, calzas de velludo para las fiestas, con sus pantuflos de lo mesmo, y los dÃ\xadas de entresemana se honraba con su vellorÃ\xad de lo mÃ¡s fino. TenÃ\xada en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que asÃ\xad ensillaba el rocÃ\xadn como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta aÃ±os; era de complexiÃ³n recia, seco de carnes, enjuto de rostro, gran madrugador y amigo de la caza. Quieren decir que tenÃ\xada el sobrenombre de Quijada, o Quesada, q
# ...

# %%
# Tu código aquí
patron = r'\bu\w*'
re.findall(patron,texto)
# Out:
# ['un', 'un', 'una', 'una', 'un', 'un']

# %% [markdown]
# ### Ejercicio 2
#
# Extrae todos los números de una cadena de texto y conviértelos a enteros.

# %%
# Tu código aquí
texo2="ssf 44 d 4 ff ef 55 6 ee 5.5"
patron = r'\d+\.?\d*'

listRes =re.findall(patron,texo2)

for item in listRes:
    print(int(float(item)))
# Out:
# 44
# 4
# 55
# 6
# 5

# %% [markdown]
# ### Recursos útiles
#
# - [regex101.com](https://regex101.com/) - expresiones regulares en línea.
# - [Documentación oficial de re](https://docs.python.org/3/library/re.html)
#
# <div style="background-color:#e6f2ff; border-left:4px solid #000047; padding:10px;">
# Las expresiones regulares son una herramienta poderosa para la limpieza y extracción de datos en proyectos de IA y ciencia de datos.
# </div>

# %% [markdown]
# # Archivos excel

# %%
import pandas as pd
# A partir de la función
ruta='Data/'
pd.read_excel(ruta+'API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\x\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\x\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# ...

# %%
# Importamos la clase ExcelFile
from pandas import ExcelFile

# %%
# A partir de la clase
obj=ExcelFile(ruta+'API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls')
obj.parse() # Importa la primera página
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\x\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\x\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# ...

# %% [markdown]
# # Archivos JSON

# %% [markdown]
# El formato JSON (JavaScript Object Notation) es ampliamente utilizado para el intercambio de datos, especialmente en aplicaciones web y APIs. Python incluye la librería estándar `json` para leer y manipular archivos JSON.

# %%
import json

json_data = '{"personas": [{"nombre": "Ana", "edad": 23}, {"nombre": "Luis", "edad": 31}]}'

# %%
from pandas import json_normalize

# %%
df_json['categories'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df_json['categories'][0]
#
# NameError: name 'df_json' is not defined

# %% [markdown]
# # Archivos XML

# %% [markdown]
# El formato XML es común para el intercambio de datos estructurados. Python ofrece la librería estándar `xml.etree.ElementTree` para analizar y extraer información de archivos XML.

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
xml_data = '''
<personas>
  <persona>
    <nombre>Ana</nombre>
    <edad>23</edad>
  </persona>
  <persona>
    <nombre>Luis</nombre>
    <edad>31</edad>
  </persona>
</personas>
'''

# %%
root = ET.fromstring(xml_data)
print('Personas extraídas del archivo XML:')
for persona in root.findall('persona'):
    nombre = persona.find('nombre').text
    edad = persona.find('edad').text
    print(f'Nombre: {nombre}, Edad: {edad}')
# Out:
# Personas extraídas del archivo XML:
# Nombre: Ana, Edad: 23
# Nombre: Luis, Edad: 31

# %% [markdown]
# ###### Ejemplo con tabla_1.xml

# %%
ruta="Data/"
archivo_1=ET.parse(ruta+'tabla_1.xml')
raiz=archivo_1.getroot()

# %%
raiz
# Out:
# <Element 'data' at 0x0000016A0B9CCCC0>

# %%
for nodo in raiz:
    print(nodo.attrib,nodo.text,nodo.tag)
    for sn in nodo:
        print(sn.attrib,sn.text,sn.tag)
# Out:
# {'name': 'Liechtenstein'}
#          country
# {} 1 rank
# {} 2008 year
# {} 141100 gdppc
# {'name': 'Singapore'}
#          country
# {} 4 rank
# {} 2011 year
# {} 59900 gdppc
# {'name': 'Panama'}
#          country
# {} 68 rank
# {} 2011 year
# {} 13600 gdppc

# %%
archivo_2=ET.parse(ruta+'tabla_2.xml')
root=archivo_2.getroot()
for nodo in root:
    print(nodo.tag,nodo.attrib,nodo.text)
# Out:
# documents {'count': 'N'}

# %%
for nodo in root:
    for subn in nodo:
        print(subn.tag,subn.attrib,subn.text)
# Out:
# document {'KEY': 'e95a9a6c790ecb95e46cf15bee517651', 'web': 'www.ubm/doc004.com'} Nevertheless, high and based on experience, fluctuating throughput levels contradict high reliability.
#
#
# document {'KEY': 'bc360cfbafc39970587547215162f0db', 'web': 'www.ubm/doc006.com'} As long as the production is not conducted on the basis of concrete customer orders, the companies objectives
#
#
# document {'KEY': '19e71144c50a8b9160b3f0955e906fce', 'web': 'www.ubm/doc005.com'} Many companies today, in different fields of operations and sizes, have access to a vast amount of data which was not available only a couple of years ago.
#
#
# document {'KEY': '21d4af9021a174f61b884606c74d9e42', 'web': 'www.ubm/doc002.com'} A famous example of a successful prediction is by the German astronomer Johann Gottfried Galle
#
#
# ...

# %%
#Extraer los datos de tabla_1.xml
d={}
for nodo in raiz:
    d[nodo.tag]=[]
for nodo in raiz:
    d[nodo.tag].append(nodo.attrib['name'])
for nodo in raiz:
    for sn in nodo:
        d[sn.tag]=[]
for nodo in raiz:
    for sn in nodo:
        d[sn.tag].append(sn.text)
d
# Out:
# {'country': ['Liechtenstein', 'Singapore', 'Panama'],
#  'rank': ['1', '4', '68'],
#  'year': ['2008', '2011', '2011'],
#  'gdppc': ['141100', '59900', '13600']}

# %%
pd.DataFrame(d)
# Out:
#          country rank  year   gdppc
# 0  Liechtenstein    1  2008  141100
# 1      Singapore    4  2011   59900
# 2         Panama   68  2011   13600

# %% [markdown]
# ```python
# df_1 = pd.DataFrame(columns = columnas)
# for nodo in raiz:
#   L = []
#   L.append(nodo.attrib['name'])
#   for sn in nodo:
#     L.append(sn.text)
#   df_1 = df_1.append(pd.DataFrame([L], columns=columnas), ignore_index=True)
# ```

# %%
archivo=ET.parse(ruta+'tabla_2.xml')
raiz=archivo.getroot()

# %%
L=[]
for n in raiz.findall('documents/document'):
    d={}
    d[n.tag]=n.text
    for k,v in n.attrib.items():
        d[k]=v
    L.append(d)
pd.DataFrame(L)

# %% [markdown]
# ---

# %%
archivo='IFC-Subscriptions-and-Voting-Power-of-Member-Count.xml'
file=ET.parse(ruta+archivo)
root=file.getroot()

for nodo in root:
    for snodo in nodo:
        print(snodo.tag,snodo.attrib,snodo.text)
        for ssnodo in snodo:
            print(ssnodo.tag,ssnodo.attrib,ssnodo.text)

# %% [markdown]
# ---

# %% [markdown]
# # Archivos SHP

# %% [markdown]
# Los archivos Shapefile (`.shp`) son un formato estándar para almacenar información geoespacial vectorial. La librería `geopandas` permite leer y manipular estos archivos de manera sencilla. Un Shapefile suele estar acompañado de otros archivos como `.shx` y `.dbf`.

# %%
# !pip install geopandas

# %%
#!pip install geopandas

# %%
# %conda !pip !conda
# %pip install geopandas

# %%
import geopandas as gpd

# %%
g_df = gpd.read_file('COVID_INDIA_POC-shp/COVID_INDIA_POC.shp')
g_df

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 8))
g_df.plot(
    ax=ax,
    column=g_df.columns[0],  # Cambia por la columna que quieras destacar
    cmap='viridis',
    edgecolor='black',
    legend=True
)
ax.set_title('COVID_INDIA_POC', fontsize=12)
ax.axis('off')
plt.show()

# %% [markdown]
# # Archivos HTML

# %%
# Leer un archivo HTML local
with open(ruta+'ejemplo.html', 'r', encoding='utf-8') as file:
    html_content = file.read()
print(html_content[:500])  # Muestra los primeros 500 caracteres

# %%
#!pip install beautifulsoup4 #Instalar BeautifulSoup si es necesario

# %%
# Analizar HTML con BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Extraer el título de la página
titulo = soup.title.string
print('Título de la página:', titulo)

# %%
# Extraer los enlaces de la página
enlaces = soup.find_all('a')
for enlace in enlaces:
    print(enlace.get('href'))

# %%
#!pip install requests # Instalar requests si es necesario
import requests

url = 'https://www.python.org/'
response = requests.get(url)
web_html = response.text

# Analizar el HTML descargado
soup_web = BeautifulSoup(web_html, 'html.parser')

# %%
print(soup_web.title)

# %% [markdown]
# ###### Ejemplo sencillo webscraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
 
url = "https://codedamn-classrooms.github.io/webscraper-python-codedamn-classroom-website/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
type(soup)

# %%
#Obtener un dataframe con la información de los productos
products = []

for price_tag in soup.find_all("h4", string=lambda s: s and s.strip().startswith("$")):
    # El nombre del producto es la cadena que sigue después del tag <a> después del precio
    product_link = price_tag.find_next("a")
    if not product_link:
        continue
    product_name = product_link.text.strip()
    product_url = product_link["href"]
    # La descripción es el siguien tag <p> después de la liga del producto
    description_tag = product_link.find_next("p")
    description = description_tag.text.strip() if description_tag else ""
    # Los numero de reviews van después de <div> 
    reviews_tag = product_link.find_next(string=lambda s: s and "review" in s)
    try:
        reviews = int(reviews_tag.strip().split()[0])
    except Exception:
        reviews = None
    # Precio
    try:
        price = float(price_tag.text.strip().replace("$", ""))
    except Exception:
        price = None
 
    products.append({
        "Product Name": product_name,
        "Price": price,
        "Description": description,
        "Reviews": reviews,
        "Product URL": product_url
    })
 
df = pd.DataFrame(products)
df

# %% [markdown]
# # Archivos imágen

# %% [markdown]
# Las imágenes RGB almacenan información de color en tres canales: Rojo (R), Verde (G) y Azul (B). Para leer y manipular imágenes en Python, se pueden usar las librerías `Pillow` (PIL), `matplotlib` y `numpy`. Esto permite acceder a los valores de los píxeles y realizar análisis o transformaciones.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
I=plt.imread(ruta+'imagen.bmp')
I.shape

# %%
type(I)

# %%
plt.imshow(I)

# %%
I[0,0,0] # pixel (0,0) de la matriz roja

# %%
plt.imshow(I[:,:,0],cmap='gray') # Matriz roja

# %%
G=I.mean(axis=2)
G.shape

# %%
plt.imshow(G)

# %%
G[0,0]

# %% [markdown]
# ### Ejemplos de aplicaciones en IA para cada tipo de archivo

# %% [markdown]
# ## 🔎 Ejemplos de aplicaciones en IA para cada tipo de archivo
#
# ### 📄 Archivos de texto:
#
# - **Análisis de sentimientos:** Procesar opiniones de usuarios para determinar si son positivas o negativas.
# - **Extracción de palabras clave:** Identificar términos importantes en grandes volúmenes de texto.
# - **Procesamiento de lenguaje natural (NLP):** Tokenización, lematización y análisis de frecuencia de palabras.
# - **Análisis de logs:** Detectar patrones o anomalías en archivos de registro.
# - **Generación automática de resúmenes:** Resumir textos extensos con modelos de IA.
# - **Reconocimiento de entidades:** Extraer nombres de personas, lugares y organizaciones.
# - **Clasificación de documentos:** Categorizar textos en temas o géneros.
# - **Traducción automática:** Convertir textos entre idiomas usando IA.
#
# ### 📊 Archivos Excel y CSV:
#
# - **Análisis exploratorio de datos (EDA):** Calcular totales, medias y tendencias.
# - **Preparación de datos para ML:** Ingeniería de características y limpieza de datos.
# - **Reportes automatizados:** Generar resúmenes y exportar resultados.
# - **Detección de anomalías:** Identificar valores atípicos.
# - **Predicción de tendencias:** Series temporales para prever ventas.
# - **Segmentación de clientes:** Agrupar clientes por patrones de compra.
# - **Visualización de datos:** Dashboards interactivos y gráficos.
#
# ### 🖼️ Archivos de imágenes RGB:
#
# - **Visión por computadora:** Clasificación de imágenes y reconocimiento facial.
# - **Procesamiento de imágenes médicas:** Detección de regiones anómalas.
# - **Extracción de características visuales:** Histogramas y patrones de color.
# - **Detección de objetos:** Localización y clasificación en imágenes.
# - **Reconstrucción 3D:** Modelos tridimensionales a partir de imágenes.
# - **Segmentación semántica:** Delimitación de regiones específicas.
# - **Realidad aumentada:** Superposición de información digital.
#
# ### 🗂️ Archivos XML:
#
# - **Integración de datos empresariales:** Extraer información de sistemas ERP.
# - **Procesamiento de datos IoT:** Leer registros de sensores.
# - **Análisis de publicaciones científicas:** Obtener títulos y autores.
# - **Intercambio de datos entre aplicaciones:** Estandarización e interoperabilidad.
# - **Validación de esquemas:** Verificar estructura y consistencia.
# - **Extracción de datos jerárquicos:** Navegación en árboles complejos.
# - **Automatización de reportes:** Generar informes estructurados.
#
# ### { } Archivos JSON:
#
# - **Consumo de APIs web:** Obtener y analizar datos en tiempo real.
# - **Almacenamiento y análisis de logs:** Procesar registros de aplicaciones.
# - **Análisis de datos móviles:** Leer resultados de encuestas y métricas.
# - **Integración de datos en tiempo real:** Sensores y dispositivos conectados.
# - **Visualización de datos:** Gráficos y mapas interactivos.
# - **Entrenamiento de modelos de IA:** Datasets estructurados para algoritmos.
# - **Validación y limpieza de datos:** Corrección de inconsistencias.
#
# ### 🗺️ Archivos Shapefile (SHP):
#
# - **Análisis geoespacial:** Distancias y relaciones espaciales.
# - **Estudios ambientales y urbanos:** Distribución de áreas verdes y zonas urbanas.
# - **Modelado de redes y transporte:** Rutas óptimas y predicción de tráfico.
# - **Análisis de riesgos naturales:** Identificación de zonas vulnerables.
# - **Visualización de mapas temáticos:** Datos demográficos y económicos.
# - **Optimización logística:** Rutas de entrega y distribución.
#
# ### 🌐 Archivos HTML:
#
# - **Web scraping:** Extracción de datos estructurados de páginas web.
# - **Construcción de datasets:** Recolección de información de múltiples páginas.
# - **Análisis de enlaces:** Estructura de redes y relaciones.
# - **Extracción de tablas:** Datos tabulares para análisis estadístico.
# - **Monitoreo de precios:** Rastrear precios en tiendas en línea.
# - **Análisis de tendencias:** Identificar temas populares en blogs y noticias.
# - **Automatización de reportes web:** Generar informes automáticos.
# - **Reconocimiento de patrones visuales:** Detección de banners y anuncios.
