# %% [markdown]
# <div style="background-color:#e6f2ff; padding:20px; border-radius:10px;">
# <img style="float:left; margin-right:20px;" src='Figures/alinco.png' width="120"/>
# <h1 style="color:#000047;">Tarea 1: Modificación de la librería de clase</h1>
# <br style="clear:both"/>
# </div>
#
# <div style="border-left:4px solid #000047; padding:10px; margin-top:10px; background:#f5f5f5;">
# <b>Objetivo:</b> Construir la librería de la clase con el objetivo de organizar código funciones y clases útilies durante el proceso del curso.
# </div>

# %% [markdown]
# Tomando en cuenta la libreria creada en clase `HyAIA`, y la función de reporte de calidad de datos `dqr()`, realizar lo siguiente:
#
# Modificar la función `dqr()` para tener lo siguiente:

# %% [markdown]
# **1.- Modificar la función dqr() para que en el reporte se agregue una columna que sea booleana boolena para representar si una columna es categórica ('Is_categorical') ('Is_categorical' True-->col categorica, False ---> numérica)**

# %%
print("El bloque de codigo en la fuicion dqr se implemento en la clase original")
                                                        
#def dqr(self):
    
    #is_categorical = pd.DataFrame(columns=['Is_categorical'])
    #for col in list(self.data.columns.values):
     #   if col in self.categoricos_columns:
      #      is_categorical.loc[col] = [True]
       # else:
        #    is_categorical.loc[col] = [False]        
  
    #return columns_names.join(data_dtypes).join(present_values).join(missing_values).join(unique_values).join(max_values).join(min_values).join(is_categorical)
# Out:
# El bloque de codigo en la fuicion dqr se implemento en la clase original

# %%
from HyAIA import HyAIA as hia
import pandas as pd
import numpy as np

df_countries = pd.read_csv('Data/countries.csv', sep=';')

hy_countries = hia(df_countries)
hy_countries.dqr()
# Out:
#                            Columns_Names   Dtypes  Present_values  \
# alpha_2                          alpha_2   object             251
# alpha_3                          alpha_3   object             252
# area                                area  float64             252
# capital                          capital   object             246
# continent                      continent   object             210
# currency_code              currency_code   object             251
# currency_name              currency_name   object             251
# eqivalent_fips_code  eqivalent_fips_code   object               1
# fips                                fips   object             249
# geoname_id                    geoname_id    int64             252
# languages                      languages   object             249
# name                                name   object             252
# neighbours                    neighbours   object             165
# numeric                          numeric    int64             252
# phone                              phone   object             247
# population                    population    int64             252
# postal_code_format    postal_code_format   object             154
# postal_code_regex      postal_code_regex   object             152
# tld                                  tld   object             250
#
#                      Missing_values  Unique_values  Max_values   Min_values  \
# alpha_2                           1            251         N/A          N/A
# alpha_3                           0            252         ZWE          ABW
# area                              0            248  17100000.0          0.0
# capital                           6            244         N/A          N/A
# continent                        42              6         N/A          N/A
# currency_code                     1            155         N/A          N/A
# currency_name                     1             82         N/A          N/A
# eqivalent_fips_code             251              1         N/A          N/A
# fips                              3            249         N/A          N/A
# geoname_id                        0            252     8505033        49518
# languages                         3            246         N/A          N/A
# name                              0            252    Zimbabwe  Afghanistan
# neighbours                       87            159         N/A          N/A
# numeric                           0            252         894            0
# phone                             5            233         N/A          N/A
# population                        0            249  1330044000            0
# postal_code_format               98             45         N/A          N/A
# postal_code_regex               100             54         N/A          N/A
# tld                               2            248         N/A          N/A
#
#                      Is_categorical
# alpha_2                        True
# alpha_3                        True
# area                          False
# capital                        True
# continent                      True
# currency_code                  True
# currency_name                  True
# eqivalent_fips_code           False
# fips                           True
# geoname_id                    False
# languages                      True
# name                           True
# neighbours                     True
# numeric                       False
# phone                          True
# population                    False
# postal_code_format             True
# postal_code_regex              True
# tld                            True

# %% [markdown]
# **2.- Modificar la función dqr() para que en el reporte se agregue una columna con las categorías de las columnas (valores unicos) que resulten ser categóricas (si las categorias > 10, no agregar esas categorias)**

# %%
from HyAIA import HyAIA as hia2
import pandas as pd
import numpy as np

df_countries = pd.read_csv('Data/countries.csv', sep=';')

hy_countries = hia2(df_countries)
hy_countries.dqr()
# Out:
#                            Columns_Names   Dtypes  Present_values  \
# alpha_2                          alpha_2   object             251
# alpha_3                          alpha_3   object             252
# area                                area  float64             252
# capital                          capital   object             246
# continent                      continent   object             210
# currency_code              currency_code   object             251
# currency_name              currency_name   object             251
# eqivalent_fips_code  eqivalent_fips_code   object               1
# fips                                fips   object             249
# geoname_id                    geoname_id    int64             252
# languages                      languages   object             249
# name                                name   object             252
# neighbours                    neighbours   object             165
# numeric                          numeric    int64             252
# phone                              phone   object             247
# population                    population    int64             252
# postal_code_format    postal_code_format   object             154
# postal_code_regex      postal_code_regex   object             152
# tld                                  tld   object             250
#
#                      Missing_values  Unique_values  Max_values   Min_values  \
# alpha_2                           1            251         N/A          N/A
# alpha_3                           0            252         ZWE          ABW
# area                              0            248  17100000.0          0.0
# capital                           6            244         N/A          N/A
# continent                        42              6         N/A          N/A
# currency_code                     1            155         N/A          N/A
# currency_name                     1             82         N/A          N/A
# eqivalent_fips_code             251              1         N/A          N/A
# fips                              3            249         N/A          N/A
# geoname_id                        0            252     8505033        49518
# languages                         3            246         N/A          N/A
# name                              0            252    Zimbabwe  Afghanistan
# neighbours                       87            159         N/A          N/A
# numeric                           0            252         894            0
# phone                             5            233         N/A          N/A
# population                        0            249  1330044000            0
# postal_code_format               98             45         N/A          N/A
# postal_code_regex               100             54         N/A          N/A
# tld                               2            248         N/A          N/A
#
#                      Is_categorical
# alpha_2                        True
# alpha_3                        True
# area                          False
# capital                        True
# continent                      True
# currency_code                  True
# currency_name                  True
# eqivalent_fips_code           False
# fips                           True
# geoname_id                    False
# languages                      True
# name                           True
# neighbours                     True
# numeric                       False
# phone                          True
# population                    False
# postal_code_format             True
# postal_code_regex              True
# tld                            True

# %% [markdown]
# **3.- Aplicar el análisis estadístico de las columnas creadas (max, min, mean, std) solo para las columnas que sean numéricas ('Is_categorical' == False)**
